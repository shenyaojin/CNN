# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lib.photo import IMAGE

# %%
import pickle
with open("./data/faces.pkl", "rb") as f:
    img_list = pickle.load(f)

# %%
size_array = []
for iter in range(len(img_list)):
    size_array.append(img_list[iter].imgsize[0])

# %%
np.unique(size_array)
# Out:
# array([ 30,  60, 120])

# %%
np.where(np.array(size_array)==120)[0][0]
# Out:
# 0

# %% [markdown]
# 5, 1, 0

# %%
# visualize the data
fig, ax = plt.subplots(1,3,figsize = (18,5))
ax[0].imshow(img_list[5].array, aspect='auto',cmap='jet')
ax[1].imshow(img_list[1].array, aspect='auto',cmap='jet')
ax[2].imshow(img_list[0].array, aspect='auto',cmap='jet')
ax[0].set_title("Low resolution", fontsize=24)
ax[1].set_title("Medium resolution", fontsize=24)
ax[2].set_title("High resolution", fontsize=24)
plt.show()
